# %%
install.packages("fma")
library(fma, help, pos = 2, lib.loc = NULL)
data("beer")
 
plot( beer )
# Out:
# Warning message:
# "le package 'fma' est en cours d'utilisation et ne sera pas installé"
# plot without title
